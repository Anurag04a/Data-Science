# %% [markdown]
# # Bar Plot

# %%
import matplotlib.pyplot as plt

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.bar(x,y)
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages")
plt.ylabel("Number")
plt.title("Practice")
plt.bar(x,y)
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
plt.bar(x,y)
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
plt.bar(x,y,width = 0.4)
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
plt.bar(x,y,width = 0.4,color="y")
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
c=["y","b","m","g"]
plt.bar(x,y,width = 0.4,color=c)
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
c=["y","b","m","g"]
plt.bar(x,y,width = 0.4,color=c,align="edge")
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
c=["y","b","m","g"]
plt.bar(x,y,width = 0.4,color=c,align="center")
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
c=["y","b","m","g"]
plt.bar(x,y,width = 0.4,color=c,align="center",edgecolor="r")
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
c=["y","b","m","g"]
plt.bar(x,y,width = 0.4,color=c,align="center",edgecolor="r",linewidth=5)
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
c=["y","b","m","g"]
plt.bar(x,y,width = 0.4,color=c,align="center",edgecolor="r",linewidth=5,linestyle=":")
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
c=["y","b","m","g"]
plt.bar(x,y,width = 0.4,color=c,align="center",edgecolor="r",linewidth=5,linestyle=":",alpha=0.4)
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
c=["y","b","m","g"]
plt.bar(x,y,width = 0.4,color=c,align="center",edgecolor="r",linewidth=5,linestyle=":",alpha=0.8)
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
c=["y","b","m","g"]
plt.bar(x,y,width = 0.4,color=c,align="center",edgecolor="r")
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
c=["y","b","m","g"]
plt.bar(x,y,width = 0.4,color=c,align="center",edgecolor="r",label="Anurag")
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
c=["y","b","m","g"]
plt.bar(x,y,width = 0.4,color=c,align="center",edgecolor="r",label="Anurag")
plt.legend()
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
c=["y","b","m","g"]
plt.bar(x,y,width = 0.4,color=c,align="center",edgecolor="r")
plt.legend("Anurag")
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
plt.bar(x,y,width = 0.4,color="r",label="Popularity")
plt.legend()
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
z = [20,30,40,50]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
plt.bar(x,y,width = 0.4,color="r",label="Popularity")
plt.bar(x,z,width = 0.4,color="r",label="Popularity1")
plt.legend()
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
z = [20,30,40,50]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
plt.bar(x,y,width = 0.4,color="r",label="Popularity")
plt.bar(x,z,width = 0.4,color="g",label="Popularity1")
plt.legend()
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
z = [20,30,40,50]
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
width=0.2
plt.bar(x,y,width,color="r",label="Popularity")
plt.bar(x,z,width,color="g",label="Popularity1")
plt.legend()
plt.show()

# %%
import numpy as np
x = ["python","c","c++","java"]
y = [85,70,60,82]
z = [20,30,40,50]
p= np.arange(len(x)) ## to get the index of x
plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)
width=0.2
plt.bar(p,y,width,color="r",label="Popularity")
plt.bar(p,z,width,color="g",label="Popularity1")
plt.legend()
plt.show()

# %%
import numpy as np

x = ["python","c","c++","java"]
y = [85,70,60,82]
z = [20,30,40,50]

width=0.2
p= np.arange(len(x)) ## to get the index of x
p1 = [j+width for j in p]

plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)

plt.bar(p,y,width,color="r",label="Popularity")
plt.bar(p1,z,width,color="g",label="Popularity1")
plt.legend()
plt.show()

# %%
import numpy as np

x = ["python","c","c++","java"]
y = [85,70,60,82]
z = [20,30,40,50]

width=0.2
p= np.arange(len(x)) ## to get the index of x
p1 = [j+width for j in p]

plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)

plt.bar(p,y,width,color="r",label="Popularity")
plt.bar(p1,z,width,color="g",label="Popularity1")

plt.xticks(p+width,x)
plt.legend()
plt.show()

# %%
import numpy as np

x = ["python","c","c++","java"]
y = [85,70,60,82]
z = [20,30,40,50]

width=0.2
p= np.arange(len(x)) ## to get the index of x
p1 = [j+width for j in p]

plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)

plt.bar(p,y,width,color="r",label="Popularity")
plt.bar(p1,z,width,color="g",label="Popularity1")

plt.xticks(p+width/2,x)
plt.legend()
plt.show()

# %%
import numpy as np

x = ["python","c","c++","java"]
y = [85,70,60,82]
z = [20,30,40,50]

width=0.2
p= np.arange(len(x)) ## to get the index of x
p1 = [j+width for j in p]

plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)

plt.bar(p,y,width,color="r",label="Popularity")
plt.bar(p1,z,width,color="g",label="Popularity1")

plt.xticks(p+width/2,x,rotation=20)
plt.legend()
plt.show()

# %%
import numpy as np

x = ["python","c","c++","java"]
y = [85,70,60,82]
z = [20,30,40,50]

width=0.2
p= np.arange(len(x)) ## to get the index of x
p1 = [j+width for j in p]

plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)

plt.barh(p,y,width,color="r",label="Popularity")
plt.barh(p1,z,width,color="g",label="Popularity1")

plt.xticks(p+width/2,x,rotation=20)
plt.legend()
plt.show()

# %%
import numpy as np

x = ["python","c","c++","java"]
y = [85,70,60,82]
z = [20,30,40,50]

width=0.2
p= np.arange(len(x)) ## to get the index of x
p1 = [j+width for j in p]

plt.xlabel("Languages",fontsize = 5)
plt.ylabel("Number",fontsize = 5)
plt.title("Practice",fontsize = 10)

plt.barh(p,y,width,color="r",label="Popularity")
plt.bar(p1,z,width,color="g",label="Popularity1")

plt.xticks(p+width/2,x,rotation=20)
plt.legend()
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5,6,7]
y = [2,3,4,1,6,7,8]
plt.scatter(x,y)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,4,1,6,7,8]
plt.scatter(day,no,color="r")
plt.title("scatter plot",fontsize=8)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,4,1,6,7,8]
colors=["r","g","y","r","b","g","k"]
plt.scatter(day,no,color=colors)
plt.title("scatter plot",fontsize=8)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,4,1,6,7,8]
plt.scatter(day,no,c="r") ## can also use c
plt.title("scatter plot",fontsize=8)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,4,1,6,7,8]
size = [200,12,25,100,8,16,500]
plt.scatter(day,no,c="r",s=size) ## can also use c
plt.title("scatter plot",fontsize=8)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,4,1,6,7,8]
colors=["r","g","y","r","b","g","k"]
size = [200,12,25,100,8,16,500]
plt.scatter(day,no,color=colors,s = size)
plt.title("scatter plot",fontsize=8)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,4,1,6,7,8]
colors=["r","g","y","r","b","g","k"]
size = [200,12,25,100,8,16,500]
plt.scatter(day,no,color=colors,s = size, alpha = 0.4)
plt.title("scatter plot",fontsize=8)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,4,1,6,7,8]
colors=["r","g","y","r","b","g","k"]
size = [200,12,25,100,8,16,500]
plt.scatter(day,no,color=colors,s = size, alpha = 0.9)
plt.title("scatter plot",fontsize=8)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,4,1,6,7,8]
colors=["r","g","y","r","b","g","k"]
size = [200,12,25,100,8,16,500]
plt.scatter(day,no,color=colors,s = size, alpha = 0.9,marker="*")
plt.title("scatter plot",fontsize=8)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,4,1,6,7,8]
colors=["r","g","y","r","b","g","k"]
size = [200,12,25,100,8,16,500]
plt.scatter(day,no,color=colors,s = size, alpha = 0.9,marker="*",edgecolor="g")
plt.title("scatter plot",fontsize=8)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,4,1,6,7,8]
colors=["r","g","y","r","b","g","k"]
size = [200,12,25,100,8,16,500]
plt.scatter(day,no,color=colors,s = size, alpha = 0.9,marker="*",edgecolor="g",linewidth=4)
plt.title("scatter plot",fontsize=8)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,4,1,6,7,8]
colors=["r","g","y","r","b","g","k"]
size = [200,12,25,100,8,16,500]
plt.scatter(day,no,color=colors,s = size, alpha = 0.9,marker="*",edgecolor="g",linewidth=1)
plt.title("scatter plot",fontsize=8)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,1,4,5,3,6]
colors=[10,49,30,29,56,20,30]
sizes = [400,300,400,300,200,100,600]
plt.scatter(day,no,c=colors,s = sizes,cmap="viridis")## color using list color bar
plt.title("scatter plot",fontsize=15)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,1,4,5,3,6]
colors=[10,49,30,29,56,20,30]
sizes = [400,300,400,300,200,100,600]
plt.scatter(day,no,c=colors,s = sizes,cmap="viridis")## color using list color bar, virdis is color map . u can use any color map
plt.colorbar()
plt.title("scatter plot",fontsize=15)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,1,4,5,3,6]
colors=[10,49,30,29,56,20,30]
sizes = [400,300,400,300,200,100,600]
plt.scatter(day,no,c=colors,s = sizes,cmap="viridis",alpha=0.5)## color using list color bar, virdis is color map . u can use any color map
plt.colorbar()
plt.title("scatter plot",fontsize=15)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,1,4,5,3,6]
colors=[10,49,30,29,56,20,30]
sizes = [400,300,400,300,200,100,600]
plt.scatter(day,no,c=colors,s = sizes,cmap="viridis",alpha=0.5)## color using list color bar, virdis is color map . u can use any color map
t = plt.colorbar()
t.set_label('ColorBar',fontsize=15)
plt.title("scatter plot",fontsize=15)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,1,4,5,3,6]
no2 = [3,2,4,5,2,7,6]
colors=[10,49,30,29,56,20,30]
sizes = [400,300,400,300,200,100,600]
plt.scatter(day,no,c=colors,s = sizes,cmap="viridis",alpha=0.5)## color using list color bar, virdis is color map . u can use any color map
plt.scatter(day,no2,c="r",s = sizes,cmap="viridis",alpha=0.5)
t = plt.colorbar()
t.set_label('ColorBar',fontsize=15)
plt.title("scatter plot",fontsize=15)
plt.xlabel("Day",fontsize=15)
plt.ylabel("Number",fontsize=15)
plt.show()
# Out:
# C:\Users\AKUMAR69\AppData\Local\Temp\ipykernel_4920\646625332.py:7: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(day,no2,c="r",s = sizes,cmap="viridis",alpha=0.5)

# %% [markdown]
# # Histogram Plot

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import random
x=np.random.randint(10,60,(50))
print(x)
# Out:
# [47 45 10 35 41 12 51 56 45 46 52 38 30 46 46 53 23 16 58 51 50 39 58 34
#  25 17 25 58 27 33 19 30 55 37 20 56 55 39 25 18 10 54 28 17 11 31 53 16
#  21 59]

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
plt.hist(no)
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
plt.hist(no)

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
plt.hist(no,color="g")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
plt.hist(no,color="g",edgecolor="r")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",bins=l,edgecolor="r")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,"auto",(0,200),edgecolor="r")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",cumulative=-1)

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",bottom=10)

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",bottom=20)

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",align="mid")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",align="left")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",align="right")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",histtype="step")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",histtype="stepfilled")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",histtype="barstacked")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",histtype="bar")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",orientation="horizontal")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",orientation="vertical")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",rwidth=0.8)

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",bins=l,edgecolor="r",log = True)

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",bins=l,edgecolor="r",log = True,label="Python")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")
plt.legend()
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",bins=l,edgecolor="r",log = True,label="Python")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")

plt.axvline(45,color="r")

plt.legend()
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",bins=l,edgecolor="r",log = True,label="Python")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")

plt.axvline(45,color="r",label="line")

plt.legend()
plt.show()

# %%
no = [47,45,10,35,41,12,51,56,45,46,52,38,30,46,46,53,23,16,58,51,50,39,58,34,25,17,25,58,27,33,19,30,55,57,20,56,55,39,25,18,10,54,28,17,11,31,53,16,21,59]
l = [10,20,30,40,50,60]
plt.hist(no,color="g",bins=l,edgecolor="r",log = True,label="Python")

plt.title("Hist")
plt.xlabel("python")
plt.ylabel("number")

plt.axvline(45,color="r",label="line")

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # PiePlot

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]

plt.pie(x)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]

plt.pie(x,labels=y)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.4,0.0,0.0,0.0]
plt.pie(x,labels=y,explode=explore)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
plt.pie(x,labels=y,explode=explore)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,radius=1.5)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%")

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.3f%%")

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=1.5)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=0.5,labeldistance=1)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=0.5,labeldistance=2)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=0.5,labeldistance=1.1)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=0.5,labeldistance=1.1,startangle=90)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=0.5,labeldistance=1.1,startangle=0)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=0.5,labeldistance=1.1,startangle=180)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=0.5,labeldistance=1.1,startangle=0,textprops={"fontsize":15})

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=1.5,labeldistance=1.1,startangle=0,textprops={"fontsize":15})

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=1.5,labeldistance=1.1,startangle=0,textprops={"fontsize":15},counterclock=False)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=1.5,labeldistance=1.1,startangle=0,textprops={"fontsize":15},counterclock=False,wedgeprops={"linewidth":20})

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=1.5,labeldistance=1.1,startangle=0,textprops={"fontsize":15},counterclock=False,wedgeprops={"linewidth":20,"width":2})

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=1.5,labeldistance=1.1,startangle=0,textprops={"fontsize":15},counterclock=False,wedgeprops={"linewidth":20,"edgecolor":"m"})

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=1.5,labeldistance=1.1,startangle=0,textprops={"fontsize":15},counterclock=False,wedgeprops={"linewidth":20,"edgecolor":"m"},center=(3,3))

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=1.5,labeldistance=1.1,startangle=0,textprops={"fontsize":15},counterclock=False,wedgeprops={"linewidth":20,"edgecolor":"m"},center=(3,6))

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=1,labeldistance=1.1,startangle=0,textprops={"fontsize":15},counterclock=False)

plt.title("Pie Chart")
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=1,labeldistance=1.1,startangle=0,textprops={"fontsize":15},counterclock=False)

plt.title("Pie Chart")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,explode=explore,colors=c,autopct="%0.1f%%",shadow= True,radius=1,labeldistance=1.1,startangle=0,textprops={"fontsize":15},counterclock=False)

plt.title("Pie Chart")
plt.legend(loc=2)
plt.show()

# %%
plt.pie([1])
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
x1 =[40,30,20,10]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y)
plt.pie(x1)
plt.title("Pie Chart")
plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
x1 =[40,30,20,10]
y = ["c","c++","java","python"]
explore = [0.1,0.0,0.0,0.0]
c= ["r","b","g","y"]
plt.pie(x,labels=y,radius=1.5)
plt.pie(x1,radius=0.5)
plt.title("Pie Chart")
plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
x1 =[40,30,20,10]
y = ["c","c++","java","python"]

c= ["r","b","g","y"]

plt.pie(x,labels=y,radius=1.5)
plt.pie(x1,radius=0.5,colors=c)
plt.title("Pie Chart")
plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
x1 =[40,30,20,10]
y = ["c","c++","java","python"]

c= ["r","b","g","y"]

plt.pie(x,labels=y,radius=1.5)
plt.pie([1],colors="w")

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
x1 =[40,30,20,10]
y = ["c","c++","java","python"]

c= ["r","b","g","y"]

plt.pie(x,labels=y,radius=1.5)
cr = plt.Circle(xy=(0,0),radius=1,facecolor="w")
plt.gca().add_artist(cr)
plt.title("Pie Chart")
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # Stem Plot

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6]
y = [2,2,5,7,3,8]
plt.stem(x,y)
plt.show()

# %%
x=[1,2,3,4,5,6]
y = [2,2,3,1,3,1]
plt.stem(x,y)
plt.show()

# %%
x=[1,2,3,4,5,6]
y = [2,2,3,1,3,1]
plt.stem(x,y,linefmt=":")
plt.show()

# %%
x=[1,2,3,4,5,6]
y = [2,2,3,1,3,1]
plt.stem(x,y,linefmt=":",markerfmt="r+")
plt.show()

# %%
x=[1,2,3,4,5,6]
y = [2,2,3,1,3,1]
plt.stem(x,y,linefmt=":",markerfmt="ro")
plt.show()

# %%
x=[1,2,3,4,5,6]
y = [2,2,3,1,3,1]
plt.stem(x,y,linefmt=":",markerfmt="ro")
plt.show()

# %%
x=[1,2,3,4,5,6]
y = [2,2,3,1,3,1]
plt.stem(x,y,linefmt=":",markerfmt="ro",bottom=1)
plt.show()

# %%
x=[1,2,3,4,5,6]
y = [2,2,3,1,3,1]
plt.stem(x,y,linefmt=":",markerfmt="ro",bottom=2)
plt.show()

# %%
x=[1,2,3,4,5,6]
y = [2,2,3,1,3,1]
plt.stem(x,y,linefmt=":",markerfmt="ro",bottom=0, basefmt="g")
plt.show()

# %%
x=[1,2,3,4,5,6]
y = [2,2,3,1,3,1]
plt.stem(x,y,linefmt=":",markerfmt="ro",bottom=0, basefmt="g",label="python")
plt.show()

# %%
x=[1,2,3,4,5,6]
y = [2,2,3,1,3,1]
plt.stem(x,y,linefmt=":",markerfmt="ro",bottom=0, basefmt="g",label="python")

plt.legend()
plt.show()

# %%
x=[1,2,3,4,5,6]
y = [2,2,3,1,3,1]
plt.stem(x,y,linefmt=":",markerfmt="ro",bottom=0, basefmt="g",label="python",orientation="horizontal")
plt.show()

# %% [markdown]
# # Box Vs Whisker plot

# %% [markdown]
# ## Box plot

# %%
import matplotlib.pyplot as plt

# %%
x =[10,20,30,40,50,60,70]
plt.boxplot(x)
plt.show()

# %%
x =[10,20,30,40,50,60,70]
plt.boxplot(x,notch= True)
plt.show()

# %%
x =[10,20,30,40,50,60,70]
plt.boxplot(x,notch= False)
plt.show()

# %%
x =[10,20,30,40,50,60,70]
plt.boxplot(x,vert= True)
plt.show()

# %%
x =[10,20,30,40,50,60,70]
plt.boxplot(x,vert= False)
plt.show()

# %%
x =[10,20,30,40,50,60,70]
plt.boxplot(x,widths=0.2)
plt.show()

# %%
x =[10,20,30,40,50,60,70]
plt.boxplot(x,widths=0.5)
plt.show()

# %%
x =[10,20,30,40,50,60,70]
plt.boxplot(x,labels=["Python"])
plt.show()

# %%
x =[10,20,30,40,50,60,70]
plt.boxplot(x,labels=["Python"],patch_artist= True)
plt.show()

# %%
x =[10,20,30,40,50,60,70]
plt.boxplot(x,labels=["Python"],patch_artist= False)
plt.show()

# %%
x =[10,20,30,40,50,60,70]
plt.boxplot(x,labels=["Python"],showmeans=True)
plt.show()

# %%
x =[10,20,30,40,50,60,70,120]
plt.boxplot(x,labels=["Python"],showmeans=True)
plt.show()

# %%
x =[10,20,30,40,50,60,70,120,130]
plt.boxplot(x,labels=["Python"],showmeans=True)
plt.show()

# %%
x =[10,20,30,40,50,60,70,120]
plt.boxplot(x,labels=["Python"],showmeans=True)
plt.show()

# %%
x =[10,20,30,40,50,60,70,120]
plt.boxplot(x,labels=["Python"],showmeans=True,whis=2)
plt.show()

# %%
x =[10,20,30,40,50,60,70,120]
plt.boxplot(x,labels=["Python"],showmeans=True,whis=1.5)
plt.show()

# %%
x =[10,20,30,40,50,60,70,120]
plt.boxplot(x,labels=["Python"],showmeans=True,sym="g")
plt.show()

# %%
x =[10,20,30,40,50,60,70,120]
plt.boxplot(x,labels=["Python"],showmeans=True,sym="g+")
plt.show()

# %%
x =[10,20,30,40,50,60,70,120]
plt.boxplot(x,labels=["Python"],showmeans=True,sym="g+",boxprops=dict(color="r"))
plt.show()

# %%
x =[10,20,30,40,50,60,70,120]
plt.boxplot(x,labels=["Python"],showmeans=True,sym="g+",boxprops=dict(color="r"),capprops=dict(color="r"))
plt.show()

# %%
x =[10,20,30,40,50,60,70,120]
plt.boxplot(x,labels=["Python"],showmeans=True,sym="g+",boxprops=dict(color="r"),capprops=dict(color="r"),whiskerprops=dict(color="r"))
plt.show()

# %%
x =[10,20,30,40,50,60,70,120]
plt.boxplot(x,labels=["Python"],showmeans=True,sym="g+",boxprops=dict(color="r"),capprops=dict(color="r"),whiskerprops=dict(color="r"),flierprops=dict(markeredgecolor="y"))
plt.show()

# %%
x =[10,20,30,40,50,60,70,120]
x1 =[10,20,40,50,30,60,90,80]
plt.boxplot(x,labels=["Python"],showmeans=True,sym="g+",boxprops=dict(color="r"),capprops=dict(color="r"),whiskerprops=dict(color="r"),flierprops=dict(markeredgecolor="y"))
plt.boxplot(x1,labels=["Python"],showmeans=True,sym="g+",boxprops=dict(color="r"),capprops=dict(color="r"),whiskerprops=dict(color="r"),flierprops=dict(markeredgecolor="y"))

plt.show()

# %%
x =[10,20,30,40,50,60,70,120]
x1 =[10,20,40,50,30,60,90,80]
y = [x,x1]
plt.boxplot(y,showmeans=True,sym="g+",boxprops=dict(color="r"),capprops=dict(color="r"),whiskerprops=dict(color="r"),flierprops=dict(markeredgecolor="y"))

plt.show()

# %%
x =[10,20,30,40,50,60,70,120]
x1 =[10,20,40,50,30,60,90,80]
y = [x,x1]
plt.boxplot(y,labels=["Python","C++"],showmeans=True,sym="g+",boxprops=dict(color="r"),capprops=dict(color="r"),whiskerprops=dict(color="r"),flierprops=dict(markeredgecolor="y"))

plt.show()

# %% [markdown]
# # Stack plot ,Area plot

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
area = [1,2,3,4,5]

plt.stackplot(x,area)

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
area = [2,4,2,3,5]

plt.stackplot(x,area)

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
area1 = [2,4,2,3,5]
area2 = [2,3,4,5,6]
area3 = [1,3,2,4,2]

l = ["area1","area2","area3"]
plt.stackplot(x,area1,area2,area3,labels=l)

plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
area1 = [2,4,2,3,5]
area2 = [2,3,4,5,6]
area3 = [1,3,2,4,2]

l = ["area1","area2","area3"]
plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","m"])

plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
area1 = [2,4,2,3,5]
area2 = [2,3,4,5,6]
area3 = [1,3,2,4,2]

l = ["area1","area2","area3"]
plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","m"],baseline="zero")

plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
area1 = [2,4,2,3,5]
area2 = [2,3,4,5,6]
area3 = [1,3,2,4,2]

l = ["area1","area2","area3"]
plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","m"],baseline="sym")

plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
area1 = [2,4,2,3,5]
area2 = [2,3,4,5,6]
area3 = [1,3,2,4,2]

l = ["area1","area2","area3"]
plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","m"],baseline="wiggle")

plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
area1 = [2,4,2,3,5]
area2 = [2,3,4,5,6]
area3 = [1,3,2,4,2]

l = ["area1","area2","area3"]
plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","m"],baseline="zero")

plt.title("Python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
area1 = [2,4,2,3,5]
area2 = [2,3,4,5,6]
area3 = [1,3,2,4,2]

l = ["area1","area2","area3"]
plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","m"],baseline="zero")

plt.title("Python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid()
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # Step Plot

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.step(x,y)

plt.show()

# %%
x = [1,2,3,4,5]
y = [2,2,3,5,4]

plt.step(x,y)

plt.show()

# %%
x = [1,2,3,4,5]
y = [2,2,3,5,4]

plt.step(x,y)

plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,2,3,5,4]

plt.step(x,y)

plt.title("python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,2,3,5,4]

plt.step(x,y,marker="o")

plt.title("python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,2,3,5,4]

plt.step(x,y,color="r",marker="o")

plt.title("python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,2,3,5,4]

plt.step(x,y,color="r",marker="o",ms=10)

plt.title("python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,2,3,5,4]

plt.step(x,y,color="r",marker="o",ms=10,mfc="g")

plt.title("python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,2,3,5,4]

plt.step(x,y,color="r",marker="o",ms=10,mfc="g",label="python")

plt.title("python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,2,3,5,4]

plt.step(x,y,color="r",marker="o",ms=10,mfc="g",label="python")

plt.title("python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend(loc=2)
plt.grid()
plt.show()

# %% [markdown]
# # Fill_Between Plot

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.plot(x,y)

plt.show()

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.plot(x,y,color="r")

plt.title("Python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.plot(x,y,color="r")
plt.fill_between(x,y)

plt.title("Python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.plot(x,y,color="r")
plt.fill_between(x=[2,4],y1=2,y2=4)

plt.title("Python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.plot(x,y,color="r")
plt.fill_between(x=[2,4],y1=2,y2=4)

plt.title("Python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
import numpy as np
x = np.array([1,2,3,4,5])
y = np.array([1,2,3,4,5])

plt.plot(x,y,color="r")
plt.fill_between(x,y,color="g",where=(x>=2)&(x<=4))

plt.title("Python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
import numpy as np
x = np.array([1,2,3,4,5])
y = np.array([1,2,3,4,5])

plt.plot(x,y,color="r")
plt.fill_between(x,y,color="g",where=(x>=2)&(x<=4),alpha = 0.5)

plt.title("Python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# # Sub Plot

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [1,2,3,4]

plt.plot(x,y,color="r")

plt.show()

# %%
x = [1,2,3,4]
y = [1,2,3,4]

plt.plot(x,y,color="r")
plt.pie([1],colors="r")

plt.show()

# %%
x = [1,2,3,4]
y = [1,2,3,4]

plt.plot(x,y,color="r")
plt.pie([1],colors="r")
x1 =[10,20,30,40]
plt.pie(x)

plt.show()

# %%
x = [1,2,3,4]
y = [1,2,3,4]

plt.plot(x,y,color="r")
plt.pie([1],colors="r")
x1 =[10,20,30,40]
plt.pie(x)

x2=["a","s","d","f"]
y2=[10,20,30,40]
plt.bar(x2,y2)

plt.show()

# %%
x = [1,2,3,4]
y = [1,2,3,4]


plt.subplot(2,2,1)
plt.plot(x,y,color="r")

plt.subplot(2,2,2)
plt.pie([1],colors="r")
x1 =[10,20,30,40]
plt.subplot(2,2,3)
plt.pie(x)

x2=["a","s","d","f"]
y2=[10,20,30,40]
plt.subplot(2,2,4)
plt.bar(x2,y2)

plt.show()

# %% [markdown]
# # Savefig

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [2,4,3,6,4]

plt.plot(x,y,color="r")
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,3,6,4]


plt.plot(x,y,color="r")
plt.savefig("line")

plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,3,6,4]


plt.plot(x,y,color="r")
plt.savefig("line1",dpi=2000) #dpi: dot per inch

plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,3,6,4]


plt.plot(x,y,color="r")
plt.savefig("line2",dpi=2000,facecolor="g")

plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,3,6,4]


plt.plot(x,y,color="r")
plt.savefig("line3.pdf",dpi=2000,facecolor="g")

plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,3,6,4]


plt.plot(x,y,color="r")
plt.savefig("line4.jpg",dpi=2000,facecolor="g")

plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,3,6,4]


plt.plot(x,y,color="r")
plt.savefig("line5",dpi=2000,facecolor="g",transparent= True)

plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,3,6,4]


plt.plot(x,y,color="r")
plt.savefig("line6",dpi=2000,facecolor="g",transparent= False)

plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,3,6,4]


plt.plot(x,y,color="r")
plt.savefig("line6",dpi=2000,facecolor="g",transparent= False,bbox_inches="tight")

plt.show()

# %% [markdown]
# # Axis Matplotlib Plot
# ## how to change axis

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,4]
plt.plot(x,y)
plt.show()

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,4]

plt.plot(x,y)

plt.xticks(x)

plt.show()

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,4]

plt.plot(x,y)

plt.xticks(x)
plt.yticks(y)
plt.show()

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,4]

plt.plot(x,y)

plt.xticks(x,labels=["Python","c","c++","java","ruby"])
plt.yticks(y)

plt.show()

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,4]

plt.plot(x,y)

# plt.xticks(x,labels=["Python","c","c++","java","ruby"])
# plt.yticks(y)
plt.xlim(0,10)

plt.show()

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,4]

plt.plot(x,y)

# plt.xticks(x,labels=["Python","c","c++","java","ruby"])
# plt.yticks(y)
plt.xlim(0,10)
plt.ylim(0,10)

plt.show()

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,4]

plt.plot(x,y)

# plt.xticks(x,labels=["Python","c","c++","java","ruby"])
# plt.yticks(y)
# plt.xlim(0,10)
# plt.ylim(0,10)

plt.axis([0,10,0,7])

plt.show()

# %% [markdown]
# # Working With Text

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,6]

plt.plot(x,y)

plt.title("Python",fontsize=15)
plt.xlabel("Days",fontsize=15)
plt.ylabel("Python",fontsize=15)

plt.text(2,5,"Java",fontsize=15,style="italic",bbox={"facecolor":"red"})

plt.show()

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,6]

plt.plot(x,y)

plt.title("Python",fontsize=15)
plt.xlabel("Days",fontsize=15)
plt.ylabel("Python",fontsize=15)

plt.text(2,5,"Java",fontsize=15,style="italic",bbox={"facecolor":"red"})
plt.annotate("python",xy=(3,2),xytext=(4,4),arrowprops=dict(facecolor="black",shrink=100))

plt.show()

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,6]

plt.plot(x,y)

plt.title("Python",fontsize=15)
plt.xlabel("Days",fontsize=15)
plt.ylabel("Python",fontsize=15)

plt.text(2,5,"Java",fontsize=15,style="italic",bbox={"facecolor":"red"})
plt.annotate("python",xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor="black",shrink=100))

plt.show()

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,6]

plt.plot(x,y)

plt.title("Python",fontsize=15)
plt.xlabel("Days",fontsize=15)
plt.ylabel("Python",fontsize=15)

# plt.text(2,5,"Java",fontsize=15,style="italic",bbox={"facecolor":"red"})
# plt.annotate("python",xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor="black",shrink=100))

plt.legend(["up"],loc=1)
plt.show()

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,6]

plt.plot(x,y)

plt.title("Python",fontsize=15)
plt.xlabel("Days",fontsize=15)
plt.ylabel("Python",fontsize=15)

# plt.text(2,5,"Java",fontsize=15,style="italic",bbox={"facecolor":"red"})
# plt.annotate("python",xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor="black",shrink=100))

plt.legend(["up"],loc=2)
plt.show()

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,6]

plt.plot(x,y)

plt.title("Python",fontsize=15)
plt.xlabel("Days",fontsize=15)
plt.ylabel("Python",fontsize=15)

# plt.text(2,5,"Java",fontsize=15,style="italic",bbox={"facecolor":"red"})
# plt.annotate("python",xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor="black",shrink=100))

plt.legend(["up"],loc=10)
plt.show()

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,6]

plt.plot(x,y)

plt.title("Python",fontsize=15)
plt.xlabel("Days",fontsize=15)
plt.ylabel("Python",fontsize=15)

# plt.text(2,5,"Java",fontsize=15,style="italic",bbox={"facecolor":"red"})
# plt.annotate("python",xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor="black",shrink=100))

plt.legend(["up"],loc=1,facecolor="Red",edgecolor="yellow",framealpha=0.5)
plt.show()

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,6]

plt.plot(x,y)

plt.title("Python",fontsize=15)
plt.xlabel("Days",fontsize=15)
plt.ylabel("Python",fontsize=15)

# plt.text(2,5,"Java",fontsize=15,style="italic",bbox={"facecolor":"red"})
# plt.annotate("python",xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor="black",shrink=100))

plt.legend(["up"],loc=1,facecolor="Red",edgecolor="yellow",framealpha=0.5,shadow=True)
plt.show()
